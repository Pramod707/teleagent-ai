# %%
import os
from dotenv import load_dotenv
from groq import Groq
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
import pandas as pd
client.models.list()
# Out:
# ModelListResponse(data=[Model(id='groq/compound-mini', created=1756949707, object='model', owned_by='Groq', active=True, context_window=131072, public_apps=None, max_completion_tokens=8192, hugging_face_id='groq/compound-beta-mini', name='Compound Mini', input_modalities=['text'], output_modalities=['text'], context_length=131072, max_output_length=8192, supported_sampling_parameters=['temperature', 'top_p', 'stop', 'seed', 'max_tokens'], supported_features=['json_mode']), Model(id='whisper-large-v3', created=1693721698, object='model', owned_by='OpenAI', active=True, context_window=448, public_apps=None, max_completion_tokens=448, hugging_face_id='openai/whisper-large-v3', name='Whisper', input_modalities=['audio'], output_modalities=['transcription'], context_length=448, max_output_length=448), Model(id='allam-2-7b', created=1737672203, object='model', owned_by='SDAIA', active=True, context_window=4096, public_apps=None, max_completion_tokens=4096, hugging_face_id='ALLaM-AI/ALLaM-2.0-7B-Instruct', name='ALLaM-2-7b', input_modalities=['text'], output_modalities=['text'], context_length=4096, max_output_length=4096, supported_sampling_parameters=['temperature', 'top_p', 'stop', 'seed', 'max_tokens'], supported_features=['json_mode']), Model(id='meta-llama/llama-prompt-guard-2-22m', created=1748632101, object='model', owned_by='Meta', active=True, context_window=512, public_apps=None, max_completion_tokens=512, name='Llama Prompt Guard 2 22M', input_modalities=['text'], output_modalities=['text'], context_length=512, max_output_length=512, pricing={'prompt': '0.00000003', 'completion': '0.00000003', 'image': '0', 'request': '0', 'input_cache_read': '0.000000015'}, supported_sampling_parameters=['temperature', 'top_p', 'stop', 'seed', 'max_tokens']), Model(id='openai/gpt-oss-120b', created=1754408224, object='model', owned_by='OpenAI', active=True, context_window=131072, public_apps=None, max_completion_tokens=65536, hugging_face_id='openai/gpt-oss-120b', name='GPT OSS 120B', input_modalities=['text'], output_modalities=['text'], context_length=131072, max_output_length=65536, pricing={'prompt': '0.00000015', 'completion': '0.0000006', 'image': '0', 'request': '0', 'input_cache_read': '0.000000075'}, supported_sampling_parameters=['temperature', 'top_p', 'stop', 'seed', 'max_tokens'], supported_features=['tools', 'json_mode', 'structured_outputs', 'reasoning']), Model(id='openai/gpt-oss-safeguard-20b', created=1761708789, object='model', owned_by='OpenAI', active=True, context_window=131072, public_apps=None, max_completion_tokens=65536, hugging_face_id='openai/gpt-oss-safeguard-20b', name='Safety GPT OSS 20B', input_modalities=['text'], output_modalities=['text'], context_length=131072, max_output_length=65536, pricing={'prompt': '0.000000075', 'completion': '0.0000003', 'image': '0', 'request': '0', 'input_cache_read': '0.0000000375'}, supported_sampling_parameters=['temperature', 'top_p', 'stop', 'seed', 'max_tokens'], supported_features=['tools', 'json_mode', 'structured_outputs', 'reasoning']), Model(id='qwen/qwen3.6-27b', created=1778288776, object='model', owned_by='Alibaba Cloud', active=True, context_window=131072, public_apps=None, max_completion_tokens=16384, hugging_face_id='Qwen/Qwen3.6-27B', name='Qwen/Qwen3.6-27B', input_modalities=['text', 'image'], output_modalities=['text'], context_length=131072, max_output_length=16384, pricing={'prompt': '0.0000006', 'completion': '0.000003', 'image': '0', 'request': '0', 'input_cache_read': '0.0000003'}, supported_sampling_parameters=['temperature', 'top_p', 'stop', 'seed', 'max_tokens'], supported_features=['tools', 'json_mode', 'reasoning']), Model(id='whisper-large-v3-turbo', created=1728413088, object='model', owned_by='OpenAI', active=True, context_window=448, public_apps=None, max_completion_tokens=448, hugging_face_id='openai/whisper-large-v3-turbo', name='Whisper Large V3 Turbo', input_modalities=['audio'], output_modalities=['transcription'], context_length=448, ma ...

# %%
pd.DataFrame(client.models.list().data)
# Out:
#                                            0                      1   \
# 0                      (id, qwen/qwen3.6-27b)  (created, 1778288776)
# 1                      (id, qwen/qwen3.8-27b)  (created, 1786984846)
# 2       (id, canopylabs/orpheus-arabic-saudi)  (created, 1765926439)
# 3                    (id, groq/compound-mini)  (created, 1756949707)
# 4                            (id, allam-2-7b)  (created, 1737672203)
# 5                    (id, openai/gpt-oss-20b)  (created, 1754407957)
# 6         (id, canopylabs/orpheus-v1-english)  (created, 1766186316)
# 7   (id, meta-llama/llama-prompt-guard-2-86m)  (created, 1748632165)
# 8          (id, openai/gpt-oss-safeguard-20b)  (created, 1761708789)
# 9                         (id, groq/compound)  (created, 1756949530)
# 10                  (id, openai/gpt-oss-120b)  (created, 1754408224)
# 11                     (id, whisper-large-v3)  (created, 1693721698)
# 12               (id, whisper-large-v3-turbo)  (created, 1728413088)
# 13  (id, meta-llama/llama-prompt-guard-2-22m)  (created, 1748632101)
#
#                  2                          3               4   \
# 0   (object, model)  (owned_by, Alibaba Cloud)  (active, True)
# 1   (object, model)  (owned_by, Alibaba Cloud)  (active, True)
# 2   (object, model)    (owned_by, Canopy Labs)  (active, True)
# 3   (object, model)           (owned_by, Groq)  (active, True)
# 4   (object, model)          (owned_by, SDAIA)  (active, True)
# 5   (object, model)         (owned_by, OpenAI)  (active, True)
# 6   (object, model)    (owned_by, Canopy Labs)  (active, True)
# 7   (object, model)           (owned_by, Meta)  (active, True)
# 8   (object, model)         (owned_by, OpenAI)  (active, True)
# 9   (object, model)           (owned_by, Groq)  (active, True)
# 10  (object, model)         (owned_by, OpenAI)  (active, True)
# 11  (object, model)         (owned_by, OpenAI)  (active, True)
# 12  (object, model)         (owned_by, OpenAI)  (active, True)
# 13  (object, model)           (owned_by, Meta)  (active, True)
#
#                           5                    6   \
# 0   (context_window, 131072)  (public_apps, None)
# 1   (context_window, 131042)  (public_apps, None)
# 2     (context_window, 4000)  (public_apps, None)
# 3   (context_window, 131072)  (public_apps, None)
# 4     (context_window, 4096)  (public_apps, None)
# 5   (context_window, 131072)  (public_apps, None)
# 6     (context_window, 4000)  (public_apps, None)
# 7      (context_window, 512)  (public_apps, None)
# 8   (context_window, 131072)  (public_apps, None)
# 9   (context_window, 131072)  (public_apps, None)
# 10  (context_window, 131072)  (public_apps, None)
# 11     (context_window, 448)  (public_apps, None)
# 12     (context_window, 448)  (public_apps, None)
# 13     (context_window, 512)  (public_apps, None)
#
#                                 7   \
# 0   (max_completion_tokens, 16384)
# 1   (max_completion_tokens, 16384)
# 2   (max_completion_tokens, 50000)
# 3    (max_completion_tokens, 8192)
# 4    (max_completion_tokens, 4096)
# 5   (max_completion_tokens, 65536)
# 6   (max_completion_tokens, 50000)
# 7     (max_completion_tokens, 512)
# 8   (max_completion_tokens, 65536)
# 9    (max_completion_tokens, 8192)
# 10  (max_completion_tokens, 65536)
# 11    (max_completion_tokens, 448)
# 12    (max_completion_tokens, 448)
# 13    (max_completion_tokens, 512)
#
#                                                    8   \
# 0                 (hugging_face_id, Qwen/Qwen3.6-27B)
# 1                            (name, Qwen/Qwen3.8-27B)
# 2            (name, Canopy Labs Orpheus Arabic Saudi)
# 3          (hugging_face_id, groq/compound-beta-mini)
# 4   (hugging_face_id, ALLaM-AI/ALLaM-2.0-7B-Instruct)
# 5               (hugging_face_id, openai/gpt-oss-20b)
# 6              (name, Canopy Labs Orpheus V1 English)
# 7                          (name, Prompt Guard 2 86M)
# 8     (hugging_face_id, openai/gpt-oss-safeguard-20b)
# 9               (hugging_face_id, groq/compound-beta)
# 10             (hugging_face_id, openai/gpt-oss-120b)
# 11         (hugging_face_id, openai/whisper-large-v3)
# 12   (hugging_face_id, openai/whisper-large-v3-turbo)
# 13                   (name, Llama Prompt Guard 2 22M)
#
#                                    9                                  10  \
# 0            (name, Qwen/Qwen3.6-27B)  (input_modalities, [text, image])
# 1   (input_modalities, [text, image])        (output_modalities, [text])
# 2          (input_modalities, [text])      (output_modalities, [speech])
# 3               (name, Compound Mini)         (input_modalities, [text])
# 4                  (name, ALLaM-2-7b)         (input_modalities, [text])
# 5                 (name, GPT OSS 20B)         (input_modalities, [text])
# 6          (input_modalities, [text])      (output_modalities, [speech])
# 7          (input_modalities, [text])        (output_modalities, [text])
# 8          (name, Safety GPT OSS 20B)         (input_modalities, [text])
# 9                    (name, Compound)         (input_modalities, [text])
# 10               (name, GPT OSS 120B)         (input_modalities, [text])
# 11                    (name, Whisper)        (input_modalities, [audio])
# 12     (name, Whisper Large V3 Turbo)        (input_modalities, [audio])
# 13         (input_modalities, [text])        (output_modalities, [text])
#
#                                       11                          12  \
# 0            (output_modalities, [text])    (context_length, 131072)
# 1               (context_length, 131042)  (max_output_length, 16384)
# 2                 (context_length, 4000)  (max_output_length, 50000)
# 3            (output_modalities, [text])    (context_length, 131072)
# 4            (output_modalities, [text])      (context_length, 4096)
# 5            (output_modalities, [text])    (context_length, 131072)
# 6                 (context_length, 4000)  (max_output_length, 50000)
# 7                  (context_length, 512)    (max_output_length, 512)
# 8            (output_modalities, [text])    (context_length, 131072)
# 9            (output_modalities, [text])    (context_length, 131072)
# 10           (output_modalities, [text])    (context_length, 131072)
# 11  (output_modalities, [transcription])       (context_length, 448)
# 12  (output_modalities, [transcription])       (context_length, 448)
# 13                 (context_length, 512)    (max_output_length, 512)
#
#                                                    13  \
# 0                          (max_output_length, 16384)
# 1   (pricing, {'prompt': '0.0000008', 'completion'...
# 2   (pricing, {'prompt': '0.00004', 'image': '0', ...
# 3                           (max_output_length, 8192)
# 4                           (max_output_length, 4096)
# 5                          (max_output_length, 65536)
# 6   (pricing, {'prompt': '0.000022', 'image': '0',...
# 7   (pricing, {'prompt': '0.00000004', 'completion...
# 8                          (max_output_length, 65536)
# 9                           (max_output_length, 8192)
# 10                         (max_output_length, 65536)
# 11                           (max_output_length, 448)
# 12                           (max_output_length, 448)
# 13  (pricing, {'prompt': '0.00000003', 'completion...
#
#                                                    14  \
# 0   (pricing, {'prompt': '0.0000006', 'completion'...
# 1   (supported_sampling_parameters, [temperature, ...
# 2                                                None
# 3   (supported_sampling_parameters, [temperature, ...
# 4   (supported_sampling_parameters, [temperature, ...
# 5   (pricing, {'prompt': '0.000000075', 'completio...
# 6                                                None
# 7   (supported_sampling_parameters, [temperature, ...
# 8   (pricing, {'prompt': '0.000000075', 'completio...
# 9   (supported_sampling_parameters, [temperature, ...
# 10  (pricing, {'prompt': '0.00000015', 'completion...
# 11                                               None
# 12                                               None
# 13  (supported_sampling_parameters, [temperature, ...
#
#                                                    15  \
# 0   (supported_sampling_parameters, [temperature, ...
# 1   (supported_features, [tools, json_mode, reason...
# 2                                                None
# 3                   (supported_features, [json_mode])
# 4                   (supported_features, [json_mode])
# 5   (supported_sampling_parameters, [temperature, ...
# 6                                                None
# 7                   (supported_features, [json_mode])
# 8   (supported_sampling_parameters, [temperature, ...
# 9                   (supported_features, [json_mode])
# 10  (supported_sampling_parameters, [temperature, ...
# 11                                               None
# 12                                               None
# 13                                               None
#
#                                                    16
# 0   (supported_features, [tools, json_mode, reason...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   (supported_features, [tools, json_mode, struct...
# 6                                                None
# 7                                                None
# 8   (supported_features, [tools, json_mode, struct...
# 9                                                None
# 10  (supported_features, [tools, json_mode, struct...
# 11                                               None
# 12                                               None
# 13                                               None

# %%
# prompt = """
# how are you ?
# """

# res = client.chat.completions.create(
#     model="llama-3.1-8b-instant",
#     messages=[{"role": "system", "content": "you are a helpful assistant"},
#              {"role": "user", "content": prompt}]
# )
# print(res)

prompt = """
how are you?
"""

res = client.chat.completions.create(
    model="groq/compound-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ]
)

print(res.choices[0].message.content)
# Out:
# I'm doing great, thanks for asking! How can I help you today?
